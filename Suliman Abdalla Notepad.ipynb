# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Suliman Abdalla**
#
# Data Scientist

# %% [markdown]
# _I am interested in data science because it is such an intresting field_

# %% [markdown]
# ### prints a text

# %%
print("Suliman's code")
# Out:
# Suliman's code

# %% [markdown]
# * Ali
# * Omar
#
# | ~Name~ | | ~Salary~ |
# | ---- | | ---- |
# | Ali | | 5000 |
# | Omar | | 4000 |
